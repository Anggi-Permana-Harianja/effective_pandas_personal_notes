# %%
import pandas as pd
import numpy as np
#url = 'https://raw.githubusercontent.com/mattharrison/datasets/master/data/2020-jetbrains-python-survey.csv'
url = 'https://github.com/mattharrison/datasets/raw/master/data/2020-jetbrains-python-survey.csv'
df = pd.read_csv(url)

import collections
counter = collections.defaultdict(list)
for col in sorted(df.columns):
    period_count = col.count('.')
    if period_count >= 2:
        part_end = 2
    else:
        part_end = 1
    parts = col.split('.')[:part_end]
    counter['.'.join(parts)].append(col)
uniq_cols = []
for cols in counter.values():
    if len(cols) == 1:
        uniq_cols.extend(cols)
        
df = (df
 [uniq_cols]
 .rename(columns=lambda c: c.replace('.', '_'))
 .assign(age=lambda df_:df_.age.str.slice(0,2).astype(float)
             .astype('Int64'),
         are_you_datascientist=lambda df_:df_.are_you_datascientist
             .replace({'Yes': True, 'No': False, np.nan: False}),
         company_size=lambda df_:df_.company_size.replace({
             'Just me': 1, 'Not sure': np.nan, 
             'More than 5,000': 5000, '2–10': 2, '11–50':11,
             '51–500': 51, '501–1,000':501,
             '1,001–5,000':1001}).astype('Int64'),
         country_live=lambda df_:df_.country_live.astype('category'),
         employment_status=lambda df_:df_.employment_status
              .fillna('Other').astype('category'),
         is_python_main=lambda df_:df_.is_python_main
              .astype('category'),
         team_size=lambda df_:df_.team_size
             .str.split(r'-', n=1, expand=True)
             .iloc[:,0].replace('More than 40 people', 41)
             .where(df_.company_size!=1, 1).astype(float),
         years_of_coding=lambda df_:df_.years_of_coding
             .replace('Less than 1 year', .5).str.extract(r'(\d+)')
             .astype(float),
         python_years=lambda df_:df_.python_years
             .replace('Less than 1 year', .5).str.extract(r'(\d+)')
             .astype(float),
         python3_ver=lambda df_:df_.python3_version_most
              .str.replace('_', '.').str.extract(r'(\d\.\d)')
              .astype(float),
         use_python_most=lambda df_:df_.use_python_most
              .fillna('Unknown')
        )
    .drop(columns=['python2_version_most'])
)
# Out:
# /home/anggi/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (152) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#     age are_you_datascientist  company_size   country_live  \
# 0    30                 False             1            NaN
# 1    21                  True          5000          India
# 2    30                 False          5000  United States
# 3  <NA>                 False          <NA>            NaN
# 4    21                 False          <NA>          Italy
#
#                                 employment_status first_learn_about_main_ide  \
# 0  Partially employed by a company / organization    Conference / User Group
# 1      Fully employed by a company / organization        School / University
# 2      Fully employed by a company / organization         Friend / Colleague
# 3                                           Other         Friend / Colleague
# 4                                         Student             Search engines
#
#   how_often_use_main_ide                      ide_main is_python_main  \
# 0                 Weekly     PyCharm Community Edition            Yes
# 1                  Daily                       VS Code            Yes
# 2                  Daily                           Vim            Yes
# 3                  Daily  PyCharm Professional Edition            Yes
# 4                  Daily                       VS Code            Yes
#
#                                     job_team  \
# 0  Work as an external consultant or trainer
# 1                             Work in a team
# 2  Work on your own project(s) independently
# 3                                        NaN
# 4  Work on your own project(s) independently
#
#                                  main_purposes  \
# 0                                     For work
# 1                   Both for work and personal
# 2                   Both for work and personal
# 3                   Both for work and personal
# 4  For personal, educational  or side projects
#
#             missing_features_main_ide  nps_main_ide  python_years  \
# 0  No, it has all the features I need           3.0           3.0
# 1  No, it has all the features I need           8.0           3.0
# 2  No, it has all the features I need          10.0           3.0
# 3                  Yes – Please list:          10.0          11.0
# 4  No, it has all the features I need          10.0           1.0
#
#   python3_version_most                                   several_projects  \
# 0           Python 3_7             Yes, I work on many different projects
# 1           Python 3_6  Yes, I work on one main and several side projects
# 2           Python 3_6  Yes, I work on one main and several side projects
# 3           Python 3_8             Yes, I work on many different projects
# 4           Python 3_8  Yes, I work on one main and several side projects
#
#    team_size                                    use_python_most  \
# 0        1.0                                            Unknown
# 1        2.0                               Software prototyping
# 2        NaN  DevOps / System administration / Writing autom...
# 3        1.0                                    Web development
# 4        1.0                                    Web development
#
#    years_of_coding  python3_ver
# 0              1.0          3.7
# 1              3.0          3.6
# 2              3.0          3.6
# 3             11.0          3.8
# 4              NaN          3.8

# %% [markdown]
# ### Pivot with styling

# %%
tmp_df = (pd.crosstab(index=[df.country_live, df.age],
                     columns=[df.use_python_most, df.python3_version_most])
          .loc[['United States'], ['Data analysis', 'Web development']]
          .style.background_gradient(cmap='viridis', axis=None))

# %%
tmp_df
# Out:
# <style type="text/css">
# #T_f330e_row0_col0, #T_f330e_row0_col5, #T_f330e_row0_col9, #T_f330e_row3_col0, #T_f330e_row4_col5, #T_f330e_row5_col5 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_f330e_row0_col1, #T_f330e_row3_col5, #T_f330e_row5_col0, #T_f330e_row5_col9 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_f330e_row0_col2, #T_f330e_row3_col4 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_f330e_row0_col3, #T_f330e_row3_col9 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_f330e_row0_col4 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_f330e_row0_col6, #T_f330e_row0_col7, #T_f330e_row1_col5, #T_f330e_row2_col0, #T_f330e_row2_col5, #T_f330e_row5_col4, #T_f330e_row5_col6 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_f330e_row0_col8, #T_f330e_row4_col6 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_f330e_row1_col0, #T_f330e_row4_col0, #T_f330e_row4_col4, #T_f330e_row4_col9, #T_f330e_row5_col1 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_f330e_row1_col1 {
#   background-color: #443b84;
#   color: #f1f1f1;
# }
# #T_f330e_row1_col2 {
#   background-color: #1f948c;
#   color: #f1f1f1;
# }
# #T_f330e_row1_col3 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_f330e_row1_col4, #T_f330e_row4_col8 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_f330e_row1_col6, #T_f330e_row4_col2 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_f330e_row1_col7 {
#   background-color: #25838e;
#   color: #f1f1f1;
# }
# #T_f330e_row1_col8 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_f330e_row1_col9, #T_f330e_row4_col1 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_f330e_row2_col1, #T_f330e_row3_col7 {
#   background-color: #3d4e8a;
#   color: #f1f1f1;
# }
# #T_f330e_row2_col2 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_f330e_row2_col3 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_f330e_row2_col4 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_f330e_row2_col6 {
#   background-color: #25858e;
#   color: #f1f1f1;
# }
# #T_f330e_row2_col7 {
#   background-color: #29af7f;
#   color: #f1f1f1;
# }
# #T_f330e_row2_col8 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_f330e_row2_col9, #T_f330e_row4_col7, #T_f330e_row5_col3 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_f330e_row3_col1 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_f330e_row3_col2 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_f330e_row3_col3 {
#   background-color: #2a788e;
#   color: #f1f1f1;
# }
# #T_f330e_row3_col6 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_f330e_row3_col8 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_f330e_row4_col3 {
#   background-color: #31678e;
#   color: #f1f1f1;
# }
# #T_f330e_row5_col2 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_f330e_row5_col7, #T_f330e_row5_col8 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f330e_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >use_python_most</th>
#       <th class="col_heading level0 col0" colspan="5">Data analysis</th>
#       <th class="col_heading level0 col5" colspan="5">Web development</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >python3_version_most</th>
#       <th class="col_heading level1 col0" >Python 3_5 or lower</th>
#       <th class="col_heading level1 col1" >Python 3_6</th>
#       <th class="col_heading level1 col2" >Python 3_7</th>
#       <th class="col_heading level1 col3" >Python 3_8</th>
#       <th class="col_heading level1 col4" >Python 3_9</th>
#       <th class="col_heading level1 col5" >Python 3_5 or lower</th>
#       <th class="col_heading level1 col6" >Python 3_6</th>
#       <th class="col_heading level1 col7" >Python 3_7</th>
#       <th class="col_heading level1 col8" >Python 3_8</th>
#       <th class="col_heading level1 col9" >Python 3_9</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country_live</th>
#       <th class="index_name level1" >age</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f330e_level0_row0" class="row_heading level0 row0" rowspan="6">United States</th>
#       <th id="T_f330e_level1_row0" class="row_heading level1 row0" >18</th>
#       <td id="T_f330e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f330e_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_f330e_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_f330e_row0_col3" class="data row0 col3" >10</td>
#       <td id="T_f330e_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_f330e_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_f330e_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_f330e_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_f330e_row0_col8" class="data row0 col8" >11</td>
#       <td id="T_f330e_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f330e_level1_row1" class="row_heading level1 row1" >21</th>
#       <td id="T_f330e_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_f330e_row1_col1" class="data row1 col1" >25</td>
#       <td id="T_f330e_row1_col2" class="data row1 col2" >74</td>
#       <td id="T_f330e_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_f330e_row1_col4" class="data row1 col4" >21</td>
#       <td id="T_f330e_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_f330e_row1_col6" class="data row1 col6" >33</td>
#       <td id="T_f330e_row1_col7" class="data row1 col7" >64</td>
#       <td id="T_f330e_row1_col8" class="data row1 col8" >103</td>
#       <td id="T_f330e_row1_col9" class="data row1 col9" >7</td>
#     </tr>
#     <tr>
#       <th id="T_f330e_level1_row2" class="row_heading level1 row2" >30</th>
#       <td id="T_f330e_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_f330e_row2_col1" class="data row2 col1" >34</td>
#       <td id="T_f330e_row2_col2" class="data row2 col2" >83</td>
#       <td id="T_f330e_row2_col3" class="data row2 col3" >116</td>
#       <td id="T_f330e_row2_col4" class="data row2 col4" >17</td>
#       <td id="T_f330e_row2_col5" class="data row2 col5" >3</td>
#       <td id="T_f330e_row2_col6" class="data row2 col6" >65</td>
#       <td id="T_f330e_row2_col7" class="data row2 col7" >90</td>
#       <td id="T_f330e_row2_col8" class="data row2 col8" >143</td>
#       <td id="T_f330e_row2_col9" class="data row2 col9" >14</td>
#     </tr>
#     <tr>
#       <th id="T_f330e_level1_row3" class="row_heading level1 row3" >40</th>
#       <td id="T_f330e_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_f330e_row3_col1" class="data row3 col1" >18</td>
#       <td id="T_f330e_row3_col2" class="data row3 col2" >39</td>
#       <td id="T_f330e_row3_col3" class="data row3 col3" >57</td>
#       <td id="T_f330e_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_f330e_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_f330e_row3_col6" class="data row3 col6" >16</td>
#       <td id="T_f330e_row3_col7" class="data row3 col7" >34</td>
#       <td id="T_f330e_row3_col8" class="data row3 col8" >73</td>
#       <td id="T_f330e_row3_col9" class="data row3 col9" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f330e_level1_row4" class="row_heading level1 row4" >50</th>
#       <td id="T_f330e_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_f330e_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_f330e_row4_col2" class="data row4 col2" >33</td>
#       <td id="T_f330e_row4_col3" class="data row4 col3" >47</td>
#       <td id="T_f330e_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_f330e_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_f330e_row4_col6" class="data row

# %%
tmp_df = (pd.crosstab(index=[df.country_live, df.age],
                     columns=[df.use_python_most, df.python3_version_most])
          .loc[['United States'], ['Data analysis', 'Web development']]
          .style.bar(subset=['Data analysis'], color='lightgreen')
          .bar(subset=['Web development'], color='blue'))

# %%
tmp_df
# Out:
# <style type="text/css">
# #T_76daf_row0_col0, #T_76daf_row0_col1, #T_76daf_row0_col2, #T_76daf_row0_col3, #T_76daf_row0_col5, #T_76daf_row0_col6, #T_76daf_row0_col7, #T_76daf_row0_col9, #T_76daf_row3_col0, #T_76daf_row4_col4, #T_76daf_row4_col5, #T_76daf_row5_col5, #T_76daf_row5_col6, #T_76daf_row5_col8 {
#   width: 10em;
#   height: 80%;
# }
# #T_76daf_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 10.5%, transparent 10.5%);
# }
# #T_76daf_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 2.2%, transparent 2.2%);
# }
# #T_76daf_row1_col0, #T_76daf_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 66.7%, transparent 66.7%);
# }
# #T_76daf_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 72.7%, transparent 72.7%);
# }
# #T_76daf_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 88.5%, transparent 88.5%);
# }
# #T_76daf_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 84.9%, transparent 84.9%);
# }
# #T_76daf_row1_col4, #T_76daf_row2_col0, #T_76daf_row2_col1, #T_76daf_row2_col2, #T_76daf_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
# }
# #T_76daf_row1_col5, #T_76daf_row2_col5, #T_76daf_row2_col6, #T_76daf_row2_col7, #T_76daf_row2_col8, #T_76daf_row2_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 100.0%, transparent 100.0%);
# }
# #T_76daf_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 48.4%, transparent 48.4%);
# }
# #T_76daf_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 70.1%, transparent 70.1%);
# }
# #T_76daf_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 70.4%, transparent 70.4%);
# }
# #T_76daf_row1_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 50.0%, transparent 50.0%);
# }
# #T_76daf_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 78.9%, transparent 78.9%);
# }
# #T_76daf_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 51.5%, transparent 51.5%);
# }
# #T_76daf_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 43.6%, transparent 43.6%);
# }
# #T_76daf_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 44.3%, transparent 44.3%);
# }
# #T_76daf_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 15.8%, transparent 15.8%);
# }
# #T_76daf_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 33.3%, transparent 33.3%);
# }
# #T_76daf_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 21.0%, transparent 21.0%);
# }
# #T_76daf_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 35.6%, transparent 35.6%);
# }
# #T_76daf_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 48.1%, transparent 48.1%);
# }
# #T_76daf_row3_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 71.4%, transparent 71.4%);
# }
# #T_76daf_row4_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 18.2%, transparent 18.2%);
# }
# #T_76daf_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 35.9%, transparent 35.9%);
# }
# #T_76daf_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 34.9%, transparent 34.9%);
# }
# #T_76daf_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 12.9%, transparent 12.9%);
# }
# #T_76daf_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 12.6%, transparent 12.6%);
# }
# #T_76daf_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 9.6%, transparent 9.6%);
# }
# #T_76daf_row4_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 14.3%, transparent 14.3%);
# }
# #T_76daf_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 33.3%, transparent 33.3%);
# }
# #T_76daf_row5_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 3.0%, transparent 3.0%);
# }
# #T_76daf_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 9.0%, transparent 9.0%);
# }
# #T_76daf_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 3.8%, transparent 3.8%);
# }
# #T_76daf_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightgreen 5.3%, transparent 5.3%);
# }
# #T_76daf_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 5.7%, transparent 5.7%);
# }
# #T_76daf_row5_col9 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,blue 7.1%, transparent 7.1%);
# }
# </style>
# <table id="T_76daf_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >use_python_most</th>
#       <th class="col_heading level0 col0" colspan="5">Data analysis</th>
#       <th class="col_heading level0 col5" colspan="5">Web development</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >python3_version_most</th>
#       <th class="col_heading level1 col0" >Python 3_5 or lower</th>
#       <th class="col_heading level1 col1" >Python 3_6</th>
#       <th class="col_heading level1 col2" >Python 3_7</th>
#       <th class="col_heading level1 col3" >Python 3_8</th>
#       <th class="col_heading level1 col4" >Python 3_9</th>
#       <th class="col_heading level1 col5" >Python 3_5 or lower</th>
#       <th class="col_heading level1 col6" >Python 3_6</th>
#       <th class="col_heading level1 col7" >Python 3_7</th>
#       <th class="col_heading level1 col8" >Python 3_8</th>
#       <th class="col_heading level1 col9" >Python 3_9</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >country_live</th>
#       <th class="index_name level1" >age</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76daf_level0_row0" class="row_heading level0 row0" rowspan="6">United States</th>
#       <th id="T_76daf_level1_row0" class="row_heading level1 row0" >18</th>
#       <td id="T_76daf_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_76daf_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_76daf_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_76daf_row0_col3" class="data row0 col3" >10</td>
#       <td id="T_76daf_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_76daf_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_76daf_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_76daf_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_76daf_row0_col8" class="data row0 col8" >11</td>
#       <td id="T_76daf_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_76daf_level1_row1" class="row_heading level1 row1" >21</th>
#       <td id="T_76daf_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_76daf_row1_col1" class="data row1 col1" >25</td>
#       <td id="T_76daf_row1_col2" class="data row1 col2" >74</td>
#       <td id="T_76daf_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_76daf_row1_col4" class="data row1 col4" >21</td>
#       <td id="T_76daf_row1_col5" class="data row1 col5" >3</td>
#       <td id="T_76daf_row1_col6" class="data row1 col6" >33</td>
#       <td id="T_76daf_row1_col7" class="
